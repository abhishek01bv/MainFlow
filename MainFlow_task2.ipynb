# %%
import pandas as pd 
import numpy as np

# %%
df= pd.read_csv('01.Data Cleaning and Preprocessing.csv') #importing dataset

# %%
df.head()
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
df.shape
# Out:
# (324, 23)

# %%
### DATA CLEANING

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (301, 23)

# %%
df.isnull().sum() #null values exist
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             4
# BF-CMratio          14
# BlowFlow            13
# ChipLevel4           1
# T-upperExt-2         1
# T-lowerExt-2         1
# UCZAA               24
# WhiteFlow-4          1
# AAWhiteSt-4        141
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        1
# Upper-HeatT-3        1
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          1
# WeakWashF            1
# SteamHeatF-3         1
# T-Top-Chips-4        1
# SulphidityL-4      141
# dtype: int64

# %%
df1=df.fillna(value=0) #clearing NULL values

# %%
df1.isnull().sum()
# Out:
# Observation        0
# Y-Kappa            0
# ChipRate           0
# BF-CMratio         0
# BlowFlow           0
# ChipLevel4         0
# T-upperExt-2       0
# T-lowerExt-2       0
# UCZAA              0
# WhiteFlow-4        0
# AAWhiteSt-4        0
# AA-Wood-4          0
# ChipMoisture-4     0
# SteamFlow-4        0
# Lower-HeatT-3      0
# Upper-HeatT-3      0
# ChipMass-4         0
# WeakLiquorF        0
# BlackFlow-2        0
# WeakWashF          0
# SteamHeatF-3       0
# T-Top-Chips-4      0
# SulphidityL-4      0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 301 entries, 0 to 307
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Observation      301 non-null    object
#  1   Y-Kappa          301 non-null    float64
#  2   ChipRate         301 non-null    float64
#  3   BF-CMratio       301 non-null    float64
#  4   BlowFlow         301 non-null    float64
#  5   ChipLevel4       301 non-null    float64
#  6   T-upperExt-2     301 non-null    float64
#  7   T-lowerExt-2     301 non-null    float64
#  8   UCZAA            301 non-null    float64
#  9   WhiteFlow-4      301 non-null    float64
#  10  AAWhiteSt-4      301 non-null    float64
#  11  AA-Wood-4        301 non-null    float64
#  12  ChipMoisture-4   301 non-null    float64
#  13  SteamFlow-4      301 non-null    float64
#  14  Lower-HeatT-3    301 non-null    float64
#  15  Upper-HeatT-3    301 non-null    float64
# ...

# %%
df2 = df.fillna(method='pad') #forward based
df2
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98    15.167      85.034  1278.345      368.564
# 300    12-11:00    21.00    15.167      88.013  1307.722      278.842
# 301    12-12:00    21.40    15.167      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df3 = df.fillna(method='bfill') #backward based
df3
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98    14.308      85.034  1278.345      368.564
# 300    12-11:00    21.00    14.308      88.013  1307.722      278.842
# 301    12-12:00    21.40    14.308      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %%
df.columns
# Out:
# Index(['Observation', 'Y-Kappa', 'ChipRate', 'BF-CMratio', 'BlowFlow',
#        'ChipLevel4 ', 'T-upperExt-2 ', 'T-lowerExt-2  ', 'UCZAA',
#        'WhiteFlow-4 ', 'AAWhiteSt-4 ', 'AA-Wood-4  ', 'ChipMoisture-4 ',
#        'SteamFlow-4 ', 'Lower-HeatT-3', 'Upper-HeatT-3 ', 'ChipMass-4 ',
#        'WeakLiquorF ', 'BlackFlow-2 ', 'WeakWashF ', 'SteamHeatF-3 ',
#        'T-Top-Chips-4 ', 'SulphidityL-4 '],
#       dtype='object')

# %%
df1.drop(['Observation'], axis=1, inplace=True) #removing unnecessary column
df1.columns
# Out:
# Index(['Y-Kappa', 'ChipRate', 'BF-CMratio', 'BlowFlow', 'ChipLevel4 ',
#        'T-upperExt-2 ', 'T-lowerExt-2  ', 'UCZAA', 'WhiteFlow-4 ',
#        'AAWhiteSt-4 ', 'AA-Wood-4  ', 'ChipMoisture-4 ', 'SteamFlow-4 ',
#        'Lower-HeatT-3', 'Upper-HeatT-3 ', 'ChipMass-4 ', 'WeakLiquorF ',
#        'BlackFlow-2 ', 'WeakWashF ', 'SteamHeatF-3 ', 'T-Top-Chips-4 ',
#        'SulphidityL-4 '],
#       dtype='object')

# %%
Q1 = df.quantile(0.25) #25 percentile
Q3 = df.quantile(0.75) #75 percentile
# Out:
# C:\Users\ABHISHEK BV\AppData\Local\Temp\ipykernel_15324\3698682088.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# C:\Users\ABHISHEK BV\AppData\Local\Temp\ipykernel_15324\3698682088.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = df.quantile(0.75)

# %%
#inter-quantile method
IQR = Q3-Q1
IQR
# Out:
# Y-Kappa              4.55000
# ChipRate             2.13400
# BF-CMratio          10.40000
# BlowFlow            94.34275
# ChipLevel4         105.91575
# T-upperExt-2        12.00925
# T-lowerExt-2         7.59525
# UCZAA                0.13200
# WhiteFlow-4        100.42925
# AAWhiteSt-4          0.10700
# AA-Wood-4            1.48025
# ChipMoisture-4       2.18675
# SteamFlow-4          8.80300
# Lower-HeatT-3        8.58325
# Upper-HeatT-3        7.81000
# ChipMass-4          19.19700
# WeakLiquorF        178.80725
# BlackFlow-2        280.29425
# WeakWashF          264.32775
# SteamHeatF-3         6.90625
# T-Top-Chips-4        2.03400
# SulphidityL-4        0.73075
# dtype: float64

# %%
lower_bound= Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

# %%
#removing Outliers using Inter-Quantile method
df1=df1[~(((df1<lower_bound)) | (df1>upper_bound)).any(axis=1)]

# %%
df1
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 3      23.60    16.478      81.011  1334.877      213.527        350.938
# 5      14.23    15.350      85.518  1171.604      198.538        344.014
# 7      22.65    14.100      91.887  1307.852      288.989        352.321
# 9      24.70    13.850      96.208  1334.892      362.511        352.372
# ..       ...       ...         ...       ...          ...            ...
# 270    21.25    14.192      91.907  1286.693      346.418        349.544
# 274    23.17    15.542      82.392  1280.501      334.242        348.771
# 276    22.70    15.517      83.008  1288.010      306.886        350.155
# 296    20.50    13.358      97.662  1304.597      377.678        347.672
# 298    20.90    15.167      84.640  1283.706      339.440        354.803
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %%
df1.describe() #Descriptive Analysis of Dataset
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  107.000000  107.000000  107.000000   107.000000   107.000000
# mean    20.711121   14.677402   86.004654  1256.900402   260.551935
# std      3.048074    1.326154    6.999506    47.243556    77.677972
# min     14.230000   10.833000   68.645000  1094.883000    61.783000
# 25%     18.365000   13.908000   80.773500  1224.645500   219.159000
# 50%     20.700000   14.808000   85.330000  1280.625000   267.787000
# 75%     23.225000   15.717500   91.763500  1289.999000   322.118500
# max     27.600000   16.817000  104.759000  1334.892000   394.234000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     107.000000      107.000000  107.000000    107.000000    107.000000
# mean      356.573963      325.443355    1.491589    604.730944      6.144832
# std         7.509403        5.365421    0.098745     61.174254      0.068717
# ...

# %%
#INSIGHTS ON Y-KAPPA
# MAXIMUM COUNT FOR EACH COLUMN IS 107
# AVERAGE FOR Y-KAPPA IS 20
# MAXIMUM AND MINIMUM ARE 27.6 AND 14.2
# IT AS DEVIATION OF 3
# THE STANDARD DEVIATION FOR ALL IS MORE THAN  0
